# %%
import numpy as np
import matplotlib.pyplot as plt
import math as mt
import cv2
import os

# %%
folder = r'D:\PhD Experimental data\Electron diffraction\Analysis'
file =  '2020-02-26_407mW_6us.png' 
diff_img = cv2.imread(os.path.join(folder,file),0)
plt.imshow(diff_img,cmap = 'RdBu_r')
plt.colorbar()
