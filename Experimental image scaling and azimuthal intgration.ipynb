# %%
import cv2
import matplotlib.pyplot as plt
import os
import numpy as np

# %%
folder = r'D:\PhD Experimental data\Electron diffraction\Analysis\18-02-2020'
filename = '2020-02-18_306mW_4us.png'

image = cv2.imread(os.path.join(folder, filename),0)
plt.imshow(image)
plt.colorbar()

# %%
plt.plot(image.ravel())

# %%
thresh_img = (image<4000)*image
plt.figure(figsize=(10,10))
plt.imshow(thresh_img, cmap = 'gray')

# %%
import diffraction_subfunctions as ds
smat = ds.rmatrix()
print(np.max(smat))
s2 = np.multiply(smat,smat)
plt.imshow(s2, cmap = 'gray')
# Out:
# 718.0111304151211

# %%
itots2 = np.multiply(thresh_img,s2)
scaled = (itots2>-50)*itots2*(itots2<500)
plt.imshow(scaled, cmap = 'gray')

# %%
plt.plot(scaled_img.ravel())
